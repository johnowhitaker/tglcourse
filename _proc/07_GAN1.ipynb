# %% [raw]
# ---
# output-file: gan1.html
# title: 'Lesson 7: GANs Part 1 - GAN Training'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Intro
#
# A simple DC-GAN
#
# Maybe note some improvements to training
