# %% [raw]
# ---
# output-file: generative_1.html
# title: Lesson 6 - Generative Modelling Intro (AutoEncoders)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# noise -> data
#
# AEs
#
# VAEs
