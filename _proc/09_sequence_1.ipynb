# %% [raw]
# ---
# output-file: sequence_1.html
# title: 'Lesson 9: Introduction to Sequence Modelling'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Idea
#
# RNNs
#
# Working with embeddings
#
# Language modelling
#
# Bonus: LSTMs?
