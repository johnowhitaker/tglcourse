# %% [raw]
# ---
# output-file: ethics.html
# title: Ethics in Generative Modelling
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Hopefully find some people for good discussions here :)
